# %% [markdown]
# # echartspy 使用说明

# %% [markdown]
# ## 手写python配置绘图

# %%
from echartspy import Echarts,Tools
import echartspy.express as ex

options={
    'xAxis':{
        'type':'category',
        'data':['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
    },
    'yAxis':{
        'type':'value'
    },
    'series':[{
        'data':[820, 932, 901, 934, 1290, 1330, 1320],
        'type':'line',
        'smooth':True
    }]
}
Echarts(options,height='300px',width='300px').render_notebook()
# Out:
# <script>
#   require.config({
#     paths: {
#       "echarts": "https://unpkg.com/echarts@5.1.2/dist/echarts.min"
#     }
#   });
# </script>
# <style>
#   #u97590603b52b433e90e397526a39ef68 {
#     width:300px;
#     height:300px;
#  }
# </style>
# <div id="u97590603b52b433e90e397526a39ef68"></div>
# <script>
#   require(['echarts'], function (echarts) {
#     var plot_u97590603b52b433e90e397526a39ef68 = echarts.init(document.getElementById('u97590603b52b433e90e397526a39ef68'));
#
#     plot_u97590603b52b433e90e397526a39ef68.setOption({
#   "xAxis": {
#     "type": "category",
#     "data": [
#       "Mon",
#       "Tue",
#       "Wed",
#       "Thu",
#       "Fri",
#       "Sat",
#       "Sun"
#     ]
#   },
#   "yAxis": {
#     "type": "value"
#   },
#   "series": [
#     {
#       "data": [
#         820,
#         932,
#         901,
#         934,
#         1290,
#         1330,
#         1320
#       ],
#       "type": "line",
#       "smooth": true
#     }
#   ]
# })
#   });
# </script>

# %% [markdown]
# ## 把JavaScript配置自动转换成python配置绘图

# %%
from echartspy import Echarts,Tools
js_str="""
{
    title: {
        text: 'Male and female height and weight distribution',
        subtext: 'Data from: Heinz 2003'
    },
    grid: {
        left: '3%',
        right: '7%',
        bottom: '7%',
        containLabel: true
    },
    tooltip: {
        // trigger: 'axis',
        showDelay: 0,
        formatter: function (params) {
            if (params.value.length > 1) {
                return params.seriesName + ' :<br/>'
                + params.value[0] + 'cm '
                + params.value[1] + 'kg ';
            }
            else {
                return params.seriesName + ' :<br/>'
                + params.name + ' : '
                + params.value + 'kg ';
            }
        },
        axisPointer: {
            show: true,
            type: 'cross',
            lineStyle: {
                type: 'dashed',
                width: 1
            }
        }
    },
    toolbox: {
        feature: {
            dataZoom: {},
            brush: {
                type: ['rect', 'polygon', 'clear']
            }
        }
    },
    brush: {
    },
    legend: {
        data: ['Female', 'Male'],
        left: 'center',
        bottom: 10
    },
    xAxis: [
        {
            type: 'value',
            scale: true,
            axisLabel: {
                formatter: '{value} cm'
            },
            splitLine: {
                show: false
            }
        }
    ],
    yAxis: [
        {
            type: 'value',
            scale: true,
            axisLabel: {
                formatter: '{value} kg'
            },
            splitLine: {
                show: false
            }
        }
    ],
    series: [
        {
            name: 'Female',
            type: 'scatter',
            emphasis: {
                focus: 'series'
            },
            data: [[161.2, 51.6], [167.5, 59.0], [159.5, 49.2], [157.0, 63.0], [155.8, 53.6],
                [170.0, 59.0], [159.1, 47.6], [166.0, 69.8], [176.2, 66.8], [160.2, 75.2],
                [166.4, 55.0], [160.0, 55.9], [152.4, 60.4], [170.2, 69.1], [162.6, 84.5],
                [170.2, 55.9], [158.8, 55.5], [172.7, 69.5], [167.6, 76.4], [162.6, 61.4],
                [167.6, 65.9], [156.2, 58.6], [175.2, 66.8], [172.1, 56.6], [162.6, 58.6],
                [160.0, 55.9], [165.1, 59.1], [182.9, 81.8], [166.4, 70.7], [165.1, 56.8],
                [177.8, 60.0], [165.1, 58.2], [175.3, 72.7], [154.9, 54.1], [158.8, 49.1],
                [172.7, 75.9], [168.9, 55.0], [161.3, 57.3], [167.6, 55.0], [165.1, 65.5],
                [175.3, 65.5], [157.5, 48.6], [163.8, 58.6], [167.6, 63.6], [165.1, 55.2],
                [165.1, 62.7], [168.9, 56.6], [162.6, 53.9], [164.5, 63.2], [176.5, 73.6],
                [168.9, 62.0], [175.3, 63.6], [159.4, 53.2], [160.0, 53.4], [170.2, 55.0],
                [162.6, 70.5], [167.6, 54.5], [162.6, 54.5], [160.7, 55.9], [160.0, 59.0],
                [157.5, 63.6], [162.6, 54.5], [152.4, 47.3], [170.2, 67.7], [165.1, 80.9],
                [172.7, 70.5], [165.1, 60.9], [170.2, 63.6], [170.2, 54.5], [170.2, 59.1],
                [161.3, 70.5], [167.6, 52.7], [167.6, 62.7], [165.1, 86.3], [162.6, 66.4],
                [152.4, 67.3], [168.9, 63.0], [170.2, 73.6], [175.2, 62.3], [175.2, 57.7],
                [160.0, 55.4], [165.1, 104.1], [174.0, 55.5], [170.2, 77.3], [160.0, 80.5],
                [167.6, 64.5], [167.6, 72.3], [167.6, 61.4], [154.9, 58.2], [162.6, 81.8],
                [175.3, 63.6], [171.4, 53.4], [157.5, 54.5], [165.1, 53.6], [160.0, 60.0],
                [174.0, 73.6], [162.6, 61.4], [174.0, 55.5], [162.6, 63.6], [161.3, 60.9],
                [156.2, 60.0], [149.9, 46.8], [169.5, 57.3], [160.0, 64.1], [175.3, 63.6],
                [169.5, 67.3], [160.0, 75.5], [172.7, 68.2], [162.6, 61.4], [157.5, 76.8],
                [176.5, 71.8], [164.4, 55.5], [160.7, 48.6], [174.0, 66.4], [163.8, 67.3]
            ],
            markArea: {
                silent: true,
                itemStyle: {
                    color: 'transparent',
                    borderWidth: 1,
                    borderType: 'dashed'
                },
                data: [[{
                    name: 'Female Data Range',
                    xAxis: 'min',
                    yAxis: 'min'
                }, {
                    xAxis: 'max',
                    yAxis: 'max'
                }]]
            },
            markPoint: {
                data: [
                    {type: 'max', name: 'Max'},
                    {type: 'min', name: 'Min'}
                ]
            },
            markLine: {
                lineStyle: {
                    type: 'solid'
                },
                data: [
                    {type: 'average', name: '平均值'},
                    { xAxis: 160 }
                ]
            }
        },
        {
            name: 'Male',
            type: 'scatter',
            emphasis: {
                focus: 'series'
            },
            data: [[174.0, 65.6], [175.3, 71.8], [193.5, 80.7], [186.5, 72.6], [187.2, 78.8],
                [172.7, 76.8], [177.8, 63.6], [177.8, 80.9], [182.9, 80.9], [170.2, 85.5],
                [167.6, 68.6], [175.3, 67.7], [165.1, 66.4], [185.4, 102.3], [181.6, 70.5],
                [172.7, 95.9], [190.5, 84.1], [179.1, 87.3], [175.3, 71.8], [170.2, 65.9],
                [193.0, 95.9], [171.4, 91.4], [177.8, 81.8], [177.8, 96.8], [167.6, 69.1],
                [167.6, 82.7], [180.3, 75.5], [182.9, 79.5], [176.5, 73.6], [186.7, 91.8],
                [188.0, 84.1], [188.0, 85.9], [177.8, 81.8], [174.0, 82.5], [177.8, 80.5],
                [171.4, 70.0], [185.4, 81.8], [185.4, 84.1], [188.0, 90.5], [188.0, 91.4],
                [182.9, 89.1], [176.5, 85.0], [175.3, 69.1], [175.3, 73.6], [188.0, 80.5],
                [188.0, 82.7], [175.3, 86.4], [170.5, 67.7], [179.1, 92.7], [177.8, 93.6],
                [175.3, 70.9], [182.9, 75.0], [170.8, 93.2], [188.0, 93.2], [180.3, 77.7],
                [177.8, 61.4], [185.4, 94.1], [168.9, 75.0], [185.4, 83.6], [180.3, 85.5],
                [174.0, 73.9], [167.6, 66.8], [182.9, 87.3], [160.0, 72.3], [180.3, 88.6],
                [167.6, 75.5], [186.7, 101.4], [175.3, 91.1], [175.3, 67.3], [175.9, 77.7],
                [175.3, 81.8], [179.1, 75.5], [181.6, 84.5], [177.8, 76.6], [182.9, 85.0],
                [177.8, 102.5], [184.2, 77.3], [179.1, 71.8], [176.5, 87.9], [188.0, 94.3],
                [174.0, 70.9], [167.6, 64.5], [170.2, 77.3], [167.6, 72.3], [188.0, 87.3],
                [174.0, 80.0], [176.5, 82.3], [180.3, 73.6], [167.6, 74.1], [188.0, 85.9],
                [180.3, 73.2], [167.6, 76.3], [183.0, 65.9], [183.0, 90.9], [179.1, 89.1],
                [170.2, 62.3], [177.8, 82.7], [179.1, 79.1], [190.5, 98.2], [177.8, 84.1],
                [180.3, 83.2], [180.3, 83.2]
            ],
            markArea: {
                silent: true,
                itemStyle: {
                    color: 'transparent',
                    borderWidth: 1,
                    borderType: 'dashed'
                },
                data: [[{
                    name: 'Male Data Range',
                    xAxis: 'min',
                    yAxis: 'min'
                }, {
                    xAxis: 'max',
                    yAxis: 'max'
                }]]
            },
            markPoint: {
                data: [
                    {type: 'max', name: 'Max'},
                    {type: 'min', name: 'Min'}
                ]
            },
            markLine: {
                lineStyle: {
                    type: 'solid'
                },
                data: [
                    {type: 'average', name: 'Average'},
                    { xAxis: 170 }
                ]
            }
        }
    ]
}
"""
options=Tools.convert_js_to_dict(js_str,print_dict=False)
Echarts(options,height='600px').render_notebook()
# Out:
# <script>
#   require.config({
#     paths: {
#       "echarts": "https://unpkg.com/echarts@5.1.2/dist/echarts.min"
#     }
#   });
# </script>
# <style>
#   #u4575423bbcd54ddba4aa2d83033d0802 {
#     width:100%;
#     height:600px;
#  }
# </style>
# <div id="u4575423bbcd54ddba4aa2d83033d0802"></div>
# <script>
#   require(['echarts'], function (echarts) {
#     var plot_u4575423bbcd54ddba4aa2d83033d0802 = echarts.init(document.getElementById('u4575423bbcd54ddba4aa2d83033d0802'));
#
#     plot_u4575423bbcd54ddba4aa2d83033d0802.setOption({
#   "title": {
#     "text": "Male and female height and weight distribution",
#     "subtext": "Data from: Heinz 2003"
#   },
#   "grid": {
#     "left": "3%",
#     "right": "7%",
#     "bottom": "7%",
#     "containLabel": true
#   },
#   "tooltip": {
#     "showDelay": 0,
#     "formatter": function (params) {            if (params.value.length > 1) {                return params.seriesName + ' :<br/>'                + params.value[0] + 'cm '                + params.value[1] + 'kg ';            }            else {                return params.seriesName + ' :<br/>'                + params.name + ' : '                + params.value + 'kg ';            }        },
#     "axisPointer": {
#       "show": true,
#       "type": "cross",
#       "lineStyle": {
#         "type": "dashed",
#         "width": 1
#       }
#     }
#   },
#   "toolbox": {
#     "feature": {
#       "dataZoom": {},
#       "brush": {
#         "type": [
#           "rect",
#           "polygon",
#           "clear"
#         ]
#       }
#     }
#   },
#   "brush": {},
#   "legend": {
#     "data": [
#       "Female",
#       "Male"
#     ],
#     "left": "center",
#     "bottom": 10
#   },
#   "xAxis": [
#     {
#       "type": "value",
#       "scale": true,
#       "axisLabel": {
#         "formatter": "{value} cm"
#       },
#       "splitLine": {
#         "show": false
#       }
#     }
#   ],
#   "yAxis": [
#     {
#       "type": "value",
#       "scale": true,
#       "axisLabel": {
#         "formatter": "{value} kg"
#       },
#       "splitLine": {
#         "show": false
#       }
#     }
#   ],
#   "series": [
#     {
#       "name": "Female",
#       "type": "scatter",
#       "emphasis": {
#         "focus": "series"
#       },
#       "data": [
#         [
#           161.2,
#           51.6
#         ],
#         [
#           167.5,
#           59.0
#         ],
#         [
#           159.5,
#           49.2
#         ],
#         [
#           157.0,
#           63.0
#         ],
#         [
#           155.8,
#           53.6
#         ],
#         [
#           170.0,
#           59.0
#         ],
#         [
#           159.1,
#           47.6
#         ],
#         [
#           166.0,
#           69.8
#         ],
#         [
#           176.2,
#           66.8
#         ],
#         [
#           160.2,
#           75.2
#         ],
#         [
#           172.5,
#           55.2
#         ],
#         [
#           170.9,
#           54.2
#         ],
#         [
#           172.9,
#           62.5
#         ],
#         [
#           153.4,
#           42.0
#         ],
#         [
#           160.0,
#           50.0
#         ],
#         [
#           147.2,
#           49.8
#         ],
#         [
#           168.2,
#           49.2
#         ],
#         [
#           175.0,
#           73.2
#         ],
#         [
#           157.0,
#           47.8
#         ],
#         [
#           167.6,
#           68.8
#         ],
#         [
#           159.5,
#           50.6
#         ],
#         [
#           175.0,
#           82.5
#         ],
#         [
#           166.8,
#           57.2
#         ],
#         [
#           176.5,
#           87.8
#         ],
#         [
#           170.2,
#           72.8
#         ],
#         [
#           174.0,
#           54.5
#         ],
#         [
#           173.0,
#           59.8
#         ],
#         [
#           179.9,
#           67.3
#         ],
#         [
#           170.5,
#           67.8
#         ],
#         [
#           160.0,
#           47.0
#         ],
#         [
#           154.4,
#           46.2
#         ],
#         [
#           162.0,
#           55.0
#         ],
#         [
#           176.5,
#           83.0
#         ],
#         [
#           160.0,
#           54.4
#         ],
#         [
#           152.0,
#           45.8
#         ],
#         [
#           162.1,
#           53.6
#         ],
#         [
#           170.0,
#           73.2
#         ],
#         [
#           160.2,
#           52.1
#         ],
#         [
#           161.3,
#           67.9
#         ],
#         [
#           166.4,
#           56.6
#         ],
#         [
#           168.9,
#           62.3
#         ],
#         [
#           163.8,
#           58.5
#         ],
#         [
#           167.6,
#           54.5
#         ],
#         [
#           160.0,
#           50.2
#         ],
#         [
#           161.3,
#           60.3
#         ],
#         [
#           167.6,
#           58.3
#         ],
#         [
#           165.1,
#           56.2
#         ],
#         [
#           160.0,
#           50.2
#         ],
#         [
#           170.0,
#           72.9
#         ],
#         [
#           157.5,
#           59.8
#         ],
#         [
#           167.6,
#           61.0
#         ],
#         [
#           160.7,
#           69.1
#         ],
#         [
#           163.2,
#           55.9
#         ],
#         [
#           152.4,
#           46.5
#         ],
#         [
#           157.5,
#           54.3
#         ],
#         [
#           168.3,
#           54.8
#         ],
#         [
#           180.3,
#           60.7
#         ],
#         [
#           165.5,
#           60.0
#         ],
#         [
#           165.0,
#           62.0
#         ],
#         [
#           164.5,
#           60.3
#         ],
#         [
#           156.0,
#           52.7
#         ],
#         [
#           160.0,
#           74.3
#         ],
#         [
#           163.0,
#           62.0
#         ],
#         [
#           165.7,
#           73.1
#         ],
#         [
#           161.0,
#           80.0
#         ],
#         [
#           162.0,
#           54.7
#         ],
#         [
#           166.0,
#           53.2
#         ],
#         [
#           174.0,
#           75.7
#         ],
#         [
#           172.7,
#           61.1
#         ],
#         [
#           167.6,
#           55.7
#         ],
#         [
#           151.1,
#           48.7
#         ],
#         [
#           164.5,
#           52.3
#         ],
#         [
#           163.5,
#           50.0
#         ],
#         [
#           152.0,
#           59.3
#         ],
#         [
#           169.0,
#           62.5
#         ],
#         [
#           164.0,
#           55.7
#         ],
#         [
#           161.2,
#           54.8
#         ],
#         [
#           155.0,
#           45.9
#         ],
#         [
#           170.0,
#           70.6
#         ],
#         [
#           176.2,
#           67.2
#         ],
#         [
#           170.0,
#           69.4
#         ],
#         [
#           162.5,
#           58.2
#         ],
#         [
#           170.3,
#           64.8
#         ],
#         [
#           164.1,
#           71.6
#         ],
#         [
#           169.5,
#           52.8
#         ],
#         [
#           163.2,
#           59.8
#         ],
#         [
#           154.5,
#           49.0
#         ],
#         [
#           159.8,
#           50.0
#         ],
#         [
#           173.2,
#           69.2
#         ],
#         [
#           170.0,
#           55.9
#         ],
#         [
#           161.4,
#           63.4
#         ],
#         [
#           169.0,
#           58.2
#         ],
#         [
#           166.2,
#           58.6
#         ],
#         [
#           159.4,
#           45.7
#         ],
#         [
#           162.5,
#           52.2
#         ],
#         [
#           159.0,
#           48.6
#         ],
#         [
#           162.8,
#           57.8
#         ],
#         [
#           159.0,
#           55.6
#         ],
#         [
#           179.8,
#           66.8
#         ],
#         [
#           162.9,
#           59.4
#         ],
#         [
#           161.0,
#           53.6
#         ],
#         [
#           151.1,
#           73.2
#         ],
#         [
#           168.2,
#           53.4
#         ],
#         [
#           168.9,
#           69.0
#         ],
#         [
#           173.2,
#           58.4
#         ],
#         [
#           171.8,
#           56.2
#         ],
#         [
#           178.0,
#           70.6
#         ],
#         [
#           164.3,
#           59.8
#         ],
#         [
#           163.0,
#           72.0
#         ],
#         [
#           168.5,
#           65.2
#         ],
#         [
#           166.8,
#           56.6

# %% [markdown]
# ## echartspy.express 绘图

# %%
from echartspy import Echarts,Tools
import echartspy.express as ex
import pandas as pd
df = pd.DataFrame(
    {
       '水果':['苹果','梨','草莓','香蕉'],
       '数量':[3,2,5,4],
       '价格':[10,9,8,5],
       '类别':['硬','硬','软','软']
    })

# %%
ex.scatter(df,x='数量',y='价格',size='数量',group='水果',size_max=50,height='250px',title='scatter').render_notebook()
# Out:
# <script>
#   require.config({
#     paths: {
#       "echarts": "https://unpkg.com/echarts@5.1.2/dist/echarts.min"
#     }
#   });
# </script>
# <style>
#   #uc045f9b17cd2486badcc9b2d780e50b0 {
#     width:100%;
#     height:250px;
#  }
# </style>
# <div id="uc045f9b17cd2486badcc9b2d780e50b0"></div>
# <script>
#   require(['echarts'], function (echarts) {
#     var plot_uc045f9b17cd2486badcc9b2d780e50b0 = echarts.init(document.getElementById('uc045f9b17cd2486badcc9b2d780e50b0'));
#
#     plot_uc045f9b17cd2486badcc9b2d780e50b0.setOption({
#   "animation": true,
#   "legend": {
#     "data": [
#       "\u68a8",
#       "\u82f9\u679c",
#       "\u9999\u8549",
#       "\u8349\u8393"
#     ]
#   },
#   "tooltip": {
#     "trigger": "item",
#     "backgroundColor": "rgba(255, 255, 255, 0.8)"
#   },
#   "xAxis": {
#     "type": "value"
#   },
#   "yAxis": {
#     "type": "value",
#     "splitLine": {
#       "show": true
#     }
#   },
#   "dataZoom": [
#     {
#       "type": "inside",
#       "xAxisIndex": 0,
#       "start": 1,
#       "end": 100
#     },
#     {
#       "type": "inside",
#       "yAxisIndex": 0,
#       "start": 1,
#       "end": 100
#     }
#   ],
#   "series": [
#     {
#       "name": "\u68a8",
#       "type": "scatter",
#       "symbolSize":                         function(val) {                         return val[2]/5*50;                        }                    ,
#       "data": [
#         [
#           2,
#           9,
#           2
#         ]
#       ]
#     },
#     {
#       "name": "\u82f9\u679c",
#       "type": "scatter",
#       "symbolSize":                         function(val) {                         return val[2]/5*50;                        }                    ,
#       "data": [
#         [
#           3,
#           10,
#           3
#         ]
#       ]
#     },
#     {
#       "name": "\u9999\u8549",
#       "type": "scatter",
#       "symbolSize":                         function(val) {                         return val[2]/5*50;                        }                    ,
#       "data": [
#         [
#           4,
#           5,
#           4
#         ]
#       ]
#     },
#     {
#       "name": "\u8349\u8393",
#       "type": "scatter",
#       "symbolSize":                         function(val) {                         return val[2]/5*50;                        }                    ,
#       "data": [
#         [
#           5,
#           8,
#           5
#         ]
#       ]
#     }
#   ],
#   "title": {
#     "text": "scatter"
#   }
# })
#   });
# </script>

# %%
ex.bar(df,x='水果',y='价格',title="bar1",height='250px').render_notebook()
# Out:
# <script>
#   require.config({
#     paths: {
#       "echarts": "https://unpkg.com/echarts@5.1.2/dist/echarts.min"
#     }
#   });
# </script>
# <style>
#   #uc73f77ae14f14c418f2242ff0184ed72 {
#     width:100%;
#     height:250px;
#  }
# </style>
# <div id="uc73f77ae14f14c418f2242ff0184ed72"></div>
# <script>
#   require(['echarts'], function (echarts) {
#     var plot_uc73f77ae14f14c418f2242ff0184ed72 = echarts.init(document.getElementById('uc73f77ae14f14c418f2242ff0184ed72'));
#
#     plot_uc73f77ae14f14c418f2242ff0184ed72.setOption({
#   "animation": true,
#   "legend": {
#     "data": []
#   },
#   "tooltip": {
#     "trigger": "item",
#     "backgroundColor": "rgba(255, 255, 255, 0.8)"
#   },
#   "xAxis": {
#     "type": "category"
#   },
#   "yAxis": {
#     "type": "value",
#     "splitLine": {
#       "show": true
#     }
#   },
#   "dataZoom": [
#     {
#       "type": "inside",
#       "xAxisIndex": 0,
#       "start": 1,
#       "end": 100
#     },
#     {
#       "type": "inside",
#       "yAxisIndex": 0,
#       "start": 1,
#       "end": 100
#     }
#   ],
#   "series": [
#     {
#       "type": "bar",
#       "data": [
#         [
#           "\u68a8",
#           9
#         ],
#         [
#           "\u82f9\u679c",
#           10
#         ],
#         [
#           "\u8349\u8393",
#           8
#         ],
#         [
#           "\u9999\u8549",
#           5
#         ]
#       ]
#     }
#   ],
#   "title": {
#     "text": "bar1"
#   }
# })
#   });
# </script>

# %%
ex.bar(df,x='水果',y='价格',group='类别',title="bar2",height='250px').render_notebook()
# Out:
# <script>
#   require.config({
#     paths: {
#       "echarts": "https://unpkg.com/echarts@5.1.2/dist/echarts.min"
#     }
#   });
# </script>
# <style>
#   #ucb1360f6861e428fa7f9a5ebde3e4fdf {
#     width:100%;
#     height:250px;
#  }
# </style>
# <div id="ucb1360f6861e428fa7f9a5ebde3e4fdf"></div>
# <script>
#   require(['echarts'], function (echarts) {
#     var plot_ucb1360f6861e428fa7f9a5ebde3e4fdf = echarts.init(document.getElementById('ucb1360f6861e428fa7f9a5ebde3e4fdf'));
#
#     plot_ucb1360f6861e428fa7f9a5ebde3e4fdf.setOption({
#   "animation": true,
#   "legend": {
#     "data": [
#       "\u786c",
#       "\u8f6f"
#     ]
#   },
#   "tooltip": {
#     "trigger": "item",
#     "backgroundColor": "rgba(255, 255, 255, 0.8)"
#   },
#   "xAxis": {
#     "type": "category"
#   },
#   "yAxis": {
#     "type": "value",
#     "splitLine": {
#       "show": true
#     }
#   },
#   "dataZoom": [
#     {
#       "type": "inside",
#       "xAxisIndex": 0,
#       "start": 1,
#       "end": 100
#     },
#     {
#       "type": "inside",
#       "yAxisIndex": 0,
#       "start": 1,
#       "end": 100
#     }
#   ],
#   "series": [
#     {
#       "name": "\u786c",
#       "type": "bar",
#       "data": [
#         [
#           "\u68a8",
#           9
#         ],
#         [
#           "\u82f9\u679c",
#           10
#         ]
#       ]
#     },
#     {
#       "name": "\u8f6f",
#       "type": "bar",
#       "data": [
#         [
#           "\u8349\u8393",
#           8
#         ],
#         [
#           "\u9999\u8549",
#           5
#         ]
#       ]
#     }
#   ],
#   "title": {
#     "text": "bar2"
#   }
# })
#   });
# </script>

# %%
ex.line(df,x='水果',y='价格',title="line",height='250px').render_notebook()
# Out:
# <script>
#   require.config({
#     paths: {
#       "echarts": "https://unpkg.com/echarts@5.1.2/dist/echarts.min"
#     }
#   });
# </script>
# <style>
#   #u3a3014526da547208bd327b702c4354e {
#     width:100%;
#     height:250px;
#  }
# </style>
# <div id="u3a3014526da547208bd327b702c4354e"></div>
# <script>
#   require(['echarts'], function (echarts) {
#     var plot_u3a3014526da547208bd327b702c4354e = echarts.init(document.getElementById('u3a3014526da547208bd327b702c4354e'));
#
#     plot_u3a3014526da547208bd327b702c4354e.setOption({
#   "animation": true,
#   "legend": {
#     "data": []
#   },
#   "tooltip": {
#     "trigger": "item",
#     "backgroundColor": "rgba(255, 255, 255, 0.8)"
#   },
#   "xAxis": {
#     "type": "category"
#   },
#   "yAxis": {
#     "type": "value",
#     "splitLine": {
#       "show": true
#     }
#   },
#   "dataZoom": [
#     {
#       "type": "inside",
#       "xAxisIndex": 0,
#       "start": 1,
#       "end": 100
#     },
#     {
#       "type": "inside",
#       "yAxisIndex": 0,
#       "start": 1,
#       "end": 100
#     }
#   ],
#   "series": [
#     {
#       "type": "line",
#       "data": [
#         [
#           "\u68a8",
#           9
#         ],
#         [
#           "\u82f9\u679c",
#           10
#         ],
#         [
#           "\u8349\u8393",
#           8
#         ],
#         [
#           "\u9999\u8549",
#           5
#         ]
#       ]
#     }
#   ],
#   "title": {
#     "text": "line"
#   }
# })
#   });
# </script>

# %%
ex.pie(df,name='水果',value='数量',title="pie1",height='350px').render_notebook()
# Out:
# <script>
#   require.config({
#     paths: {
#       "echarts": "https://unpkg.com/echarts@5.1.2/dist/echarts.min"
#     }
#   });
# </script>
# <style>
#   #u7f02ddac71394e9ebc8a5ed3de9bd61e {
#     width:100%;
#     height:350px;
#  }
# </style>
# <div id="u7f02ddac71394e9ebc8a5ed3de9bd61e"></div>
# <script>
#   require(['echarts'], function (echarts) {
#     var plot_u7f02ddac71394e9ebc8a5ed3de9bd61e = echarts.init(document.getElementById('u7f02ddac71394e9ebc8a5ed3de9bd61e'));
#
#     plot_u7f02ddac71394e9ebc8a5ed3de9bd61e.setOption({
#   "title": {
#     "text": "pie1"
#   },
#   "tooltip": {
#     "trigger": "item",
#     "formatter": "{a} <br/>{b} : {c} ({d}%)"
#   },
#   "legend": {
#     "left": "center",
#     "show": true,
#     "top": "top",
#     "data": [
#       "\u68a8",
#       "\u82f9\u679c",
#       "\u8349\u8393",
#       "\u9999\u8549"
#     ]
#   },
#   "series": [
#     {
#       "name": "pie1",
#       "type": "pie",
#       "radius": [
#         20,
#         140
#       ],
#       "center": [
#         "25%",
#         "50%"
#       ],
#       "roseType": false,
#       "itemStyle": {
#         "borderRadius": 5
#       },
#       "label": {
#         "show": false
#       },
#       "emphasis": {
#         "label": {
#           "show": true
#         }
#       },
#       "data": [
#         {
#           "name": "\u68a8",
#           "value": 2
#         },
#         {
#           "name": "\u82f9\u679c",
#           "value": 3
#         },
#         {
#           "name": "\u8349\u8393",
#           "value": 5
#         },
#         {
#           "name": "\u9999\u8549",
#           "value": 4
#         }
#       ]
#     }
#   ]
# })
#   });
# </script>

# %%
ex.pie(df,name='水果',value='数量',rose_type='area',title="pie2",height='350px').render_notebook()
# Out:
# <script>
#   require.config({
#     paths: {
#       "echarts": "https://unpkg.com/echarts@5.1.2/dist/echarts.min"
#     }
#   });
# </script>
# <style>
#   #u7af0505125744678a43551ad2edb2162 {
#     width:100%;
#     height:350px;
#  }
# </style>
# <div id="u7af0505125744678a43551ad2edb2162"></div>
# <script>
#   require(['echarts'], function (echarts) {
#     var plot_u7af0505125744678a43551ad2edb2162 = echarts.init(document.getElementById('u7af0505125744678a43551ad2edb2162'));
#
#     plot_u7af0505125744678a43551ad2edb2162.setOption({
#   "title": {
#     "text": "pie2"
#   },
#   "tooltip": {
#     "trigger": "item",
#     "formatter": "{a} <br/>{b} : {c} ({d}%)"
#   },
#   "legend": {
#     "left": "center",
#     "show": true,
#     "top": "top",
#     "data": [
#       "\u68a8",
#       "\u82f9\u679c",
#       "\u8349\u8393",
#       "\u9999\u8549"
#     ]
#   },
#   "series": [
#     {
#       "name": "pie2",
#       "type": "pie",
#       "radius": [
#         20,
#         140
#       ],
#       "center": [
#         "25%",
#         "50%"
#       ],
#       "roseType": "area",
#       "itemStyle": {
#         "borderRadius": 5
#       },
#       "label": {
#         "show": false
#       },
#       "emphasis": {
#         "label": {
#           "show": true
#         }
#       },
#       "data": [
#         {
#           "name": "\u68a8",
#           "value": 2
#         },
#         {
#           "name": "\u82f9\u679c",
#           "value": 3
#         },
#         {
#           "name": "\u8349\u8393",
#           "value": 5
#         },
#         {
#           "name": "\u9999\u8549",
#           "value": 4
#         }
#       ]
#     }
#   ]
# })
#   });
# </script>

# %%
ex.pie(df,name='水果',value='数量',rose_type='radius',title="pie2",height='350px').render_notebook()
# Out:
# <script>
#   require.config({
#     paths: {
#       "echarts": "https://unpkg.com/echarts@5.1.2/dist/echarts.min"
#     }
#   });
# </script>
# <style>
#   #u9a976fd8e3834d2987a66e08e2fb487f {
#     width:100%;
#     height:350px;
#  }
# </style>
# <div id="u9a976fd8e3834d2987a66e08e2fb487f"></div>
# <script>
#   require(['echarts'], function (echarts) {
#     var plot_u9a976fd8e3834d2987a66e08e2fb487f = echarts.init(document.getElementById('u9a976fd8e3834d2987a66e08e2fb487f'));
#
#     plot_u9a976fd8e3834d2987a66e08e2fb487f.setOption({
#   "title": {
#     "text": "pie2"
#   },
#   "tooltip": {
#     "trigger": "item",
#     "formatter": "{a} <br/>{b} : {c} ({d}%)"
#   },
#   "legend": {
#     "left": "center",
#     "show": true,
#     "top": "top",
#     "data": [
#       "\u68a8",
#       "\u82f9\u679c",
#       "\u8349\u8393",
#       "\u9999\u8549"
#     ]
#   },
#   "series": [
#     {
#       "name": "pie2",
#       "type": "pie",
#       "radius": [
#         20,
#         140
#       ],
#       "center": [
#         "25%",
#         "50%"
#       ],
#       "roseType": "radius",
#       "itemStyle": {
#         "borderRadius": 5
#       },
#       "label": {
#         "show": false
#       },
#       "emphasis": {
#         "label": {
#           "show": true
#         }
#       },
#       "data": [
#         {
#           "name": "\u68a8",
#           "value": 2
#         },
#         {
#           "name": "\u82f9\u679c",
#           "value": 3
#         },
#         {
#           "name": "\u8349\u8393",
#           "value": 5
#         },
#         {
#           "name": "\u9999\u8549",
#           "value": 4
#         }
#       ]
#     }
#   ]
# })
#   });
# </script>

# %%
from stocksdk import *
df=api.get_price("000001.XSHE")
ex.candlestick(df.reset_index(),left='5%',mas=[5,10,30],title='平安银行').render_notebook()
# Out:
# <script>
#   require.config({
#     paths: {
#       "echarts": "https://unpkg.com/echarts@5.1.2/dist/echarts.min"
#     }
#   });
# </script>
# <style>
#   #u1c332f713a7d48409dbcd7b6d6db79e0 {
#     width:100%;
#     height:600px;
#  }
# </style>
# <div id="u1c332f713a7d48409dbcd7b6d6db79e0"></div>
# <script>
#   require(['echarts'], function (echarts) {
#     var plot_u1c332f713a7d48409dbcd7b6d6db79e0 = echarts.init(document.getElementById('u1c332f713a7d48409dbcd7b6d6db79e0'));
#
#     plot_u1c332f713a7d48409dbcd7b6d6db79e0.setOption({
#   "animation": false,
#   "title": {
#     "text": "\u5e73\u5b89\u94f6\u884c"
#   },
#   "legend": {
#     "top": 10,
#     "left": "center",
#     "data": [
#       "K\u7ebf",
#       "MA5",
#       "MA10",
#       "MA30"
#     ]
#   },
#   "tooltip": {
#     "trigger": "axis",
#     "axisPointer": {
#       "type": "cross"
#     },
#     "borderWidth": 1,
#     "borderColor": "#ccc",
#     "padding": 10,
#     "formatter":                 function(params){                    var dt = params[0]['axisValue'];                    var labels = [];                    labels.push('\u65f6\u95f4: ' + dt + '<br/>');                    params.sort(function(a, b) {                      if (a.seriesName < b.seriesName ) {return -1;}                      else if (a.seriesName > b.seriesName ) {return 1;}                      else{ return 0;}                    });                    for (var i=0;i<params.length;i++)                    {                        var param= params[i];                       if(param.seriesType =='candlestick'){                         labels.push('open: ' + param.data[1] + '<br/>');                         labels.push('close: ' + param.data[2] + '<br/>');                         labels.push('low: ' + param.data[3] + '<br/>');                         labels.push('high: ' + param.data[4] + '<br/>');                       }else{                         labels.push(param.seriesName+': ' + param.data + '<br/>');                       }                    }                    return labels.join('');                },
#     "textStyle": {
#       "color": "#000"
#     },
#     "position":                 function (pos, params, el, elRect, size){                    var obj = {top: 10};                    obj[['left', 'right'][+(pos[0] < size.viewSize[0] / 2)]] = 30;                    return obj;                }
#   },
#   "axisPointer": {
#     "link": {
#       "xAxisIndex": "all"
#     },
#     "label": {
#       "backgroundColor": "#777"
#     }
#   },
#   "grid": [
#     {
#       "left": "5%",
#       "right": "0%",
#       "height": "70%"
#     },
#     {
#       "left": "5%",
#       "right": "0%",
#       "top": "71%",
#       "height": "16%"
#     }
#   ],
#   "xAxis": [
#     {
#       "type": "category",
#       "data": [
#         "2019-07-01",
#         "2019-07-02",
#         "2019-07-03",
#         "2019-07-04",
#         "2019-07-05",
#         "2019-07-08",
#         "2019-07-09",
#         "2019-07-10",
#         "2019-07-11",
#         "2019-07-12",
#         "2019-07-15",
#         "2019-07-16",
#         "2019-07-17",
#         "2019-07-18",
#         "2019-07-19",
#         "2019-07-22",
#         "2019-07-23",
#         "2019-07-24",
#         "2019-07-25",
#         "2019-07-26",
#         "2019-07-29",
#         "2019-07-30",
#         "2019-07-31",
#         "2019-08-01",
#         "2019-08-02",
#         "2019-08-05",
#         "2019-08-06",
#         "2019-08-07",
#         "2019-08-08",
#         "2019-08-09",
#         "2019-08-12",
#         "2019-08-13",
#         "2019-08-14",
#         "2019-08-15",
#         "2019-08-16",
#         "2019-08-19",
#         "2019-08-20",
#         "2019-08-21",
#         "2019-08-22",
#         "2019-08-23",
#         "2019-08-26",
#         "2019-08-27",
#         "2019-08-28",
#         "2019-08-29",
#         "2019-08-30",
#         "2019-09-02",
#         "2019-09-03",
#         "2019-09-04",
#         "2019-09-05",
#         "2019-09-06",
#         "2019-09-09",
#         "2019-09-10",
#         "2019-09-11",
#         "2019-09-12",
#         "2019-09-16",
#         "2019-09-17",
#         "2019-09-18",
#         "2019-09-19",
#         "2019-09-20",
#         "2019-09-23",
#         "2019-09-24",
#         "2019-09-25",
#         "2019-09-26",
#         "2019-09-27",
#         "2019-09-30",
#         "2019-10-08",
#         "2019-10-09",
#         "2019-10-10",
#         "2019-10-11",
#         "2019-10-14",
#         "2019-10-15",
#         "2019-10-16",
#         "2019-10-17",
#         "2019-10-18",
#         "2019-10-21",
#         "2019-10-22",
#         "2019-10-23",
#         "2019-10-24",
#         "2019-10-25",
#         "2019-10-28",
#         "2019-10-29",
#         "2019-10-30",
#         "2019-10-31",
#         "2019-11-01",
#         "2019-11-04",
#         "2019-11-05",
#         "2019-11-06",
#         "2019-11-07",
#         "2019-11-08",
#         "2019-11-11",
#         "2019-11-12",
#         "2019-11-13",
#         "2019-11-14",
#         "2019-11-15",
#         "2019-11-18",
#         "2019-11-19",
#         "2019-11-20",
#         "2019-11-21",
#         "2019-11-22",
#         "2019-11-25",
#         "2019-11-26",
#         "2019-11-27",
#         "2019-11-28",
#         "2019-11-29",
#         "2019-12-02",
